# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

# %%
x = 100 + 15 * np.random.randn(1000)

# %%
n,bins,_= plt.hist(x, bins=20,edgecolor='black',normed=1)
y=mlab.normpdf(bins,100,15)
plt.plot(bins,y,'r')
# Out:
# C:\Users\Faradars-pc2\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
